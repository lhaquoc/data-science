# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
sns.set_theme()

# %% [markdown]
# ## Numerical Plots
# * Distribution: Histogram, KDE (Kernel Density Estimation), Dist Plot
# * Bar Plot
# * Count Plot
# * Facet Plot
# * Box Plot
# * Join Plot
# * Pair Plot
# * Heat Map

# %% [markdown]
# ### Distribution lot
# * Univariate distribution of observations

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips_df['total_bill']);

# %%
tips_df['total_bill'].value_counts().sort_values(ascending=False)
# Out:
# 13.42    3
# 7.25     2
# 21.01    2
# 20.69    2
# 10.34    2
#         ..
# 29.03    1
# 27.18    1
# 22.67    1
# 17.82    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %% [markdown]
# ### KDE Plot
# * KDE plot is a method for visualising the distribution of observations in a dataser, analgous to a histogram
# * KDE presents the data using a continuous probability density curve in one or more dimensions

# %%
sns.kdeplot(data=tips_df['total_bill']);

# %% [markdown]
# ### Dist Plot

# %%
sns.displot(data=tips_df, x='total_bill', col='time', kde=True);

# %% [markdown]
# ## Categorical Plots

# %% [markdown]
# ### Bar Plots

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(data=tips_df, x='sex', y='tip', estimator=np.mean);

# %% [markdown]
# ### Count Plot

# %%
tips_df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(data=tips_df, x='sex');

# %% [markdown]
# ### Box Plot
# * Identify outliers
# * Check if data is symetrical
# * Determine how tighly data is grouped

# %%
sns.boxplot(data=tips_df, x='day', y='total_bill', hue='sex', palette='Blues');
plt.legend(loc=0);

# %% [markdown]
# ### Facet Grid

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_fg = sns.FacetGrid(data=tips_df, row='smoker', col='time');
tips_fg.map(sns.scatterplot, 'total_bill', 'tip');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 tips_fg = sns.FacetGrid(data=tips_df, row='smoker', col='time');
#       2 tips_fg.map(sns.scatterplot, 'total_bill', 'tip')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:352, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     350     row_names = []
#     351 else:
# --> 352     row_names = categorical_order(data[row], row_order)
#     354 if col is None:
#     355     col_names = []
#
# TypeError: 'FacetGrid' object is not subscriptable
