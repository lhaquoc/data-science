# %%
### Data Visualisation California Cities

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
cities = pd.read_csv('./data/california_cities.csv')
cities.head()
cities['area_total_km2'].sort_values(ascending=False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
# Extract longtitude, latitude
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']
plt.figure(figsize=(8, 6))
plt.style.use('seaborn')
# Plot using Pyplot API
plt.scatter(lon, lat, c=np.log10(population), cmap='viridis', s=area, alpha=0.5)
plt.axis('equal')
plt.xlabel('Longtitude')
plt.ylabel('Latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)

# Create the legend for city's size
area_range = [50, 100, 300, 500]
for area in area_range:
    plt.scatter([], [], s=area, c='k', alpha=0.4, label=str(area) + 'km$^2$')
plt.legend(labelspacing=1, title='City Area')
plt.title('California Cities: Population and Area distribution')
# Out:
# /var/folders/22/kj2_xl8n2wzf45q7prq2qfhc0000gn/T/ipykernel_21212/3456921433.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(label='log$_{10}$(population)')
# Text(0.5, 1.0, 'California Cities: Population and Area distribution')
